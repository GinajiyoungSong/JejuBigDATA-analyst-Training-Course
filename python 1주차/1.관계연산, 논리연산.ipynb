# %%
# 비교연산자( >=, <= , ==, < , > )와 논리 연산자 ( and, or, not )

a = 20
b = 10
c = a > 10 and b < 50
print(c)                # R언어에서는 and 연산자를 썻다면


c = 10 < a < 50        # 파이썬에선 and 없이도 가능하다
print(c)
# Out:
# True
# True

# %%
#swap  가능

x = 5
y = 6
x, y = y, x #return값이 2개 이상도 가능
print(x, y)
