# %%
city = "1,2,3".split(',')
city
# Out:
# ['1', '2', '3']

# %%
print(city)

#print 함수를 쓰면 out창에 안나타나는데 ? 뭐의 차이인거지??
# Out:
# ['1', '2', '3']

# %%
','.join(city)
# Out:
# '1,2,3'

# %%
s= "gina"
print(s.capitalize())

s.find('i')
# Out:
# Gina
# 1

# %%
s.find('y') # -1 이 뭔지 모르겠음, 안나왔으면 0 인거지 왜 -1 이야????
# Out:
# -1

# %%
s.count('na')
# Out:
# 1

# %%
s.isdigit()
# Out:
# False

# %%
s.replace('g','G')
# Out:
# 'Gina'

# %%
list ='4,7,9'.split(',')
print(list)
print(sum(list)) #여기에 list 에는 문자열로 인식됨
# Out:
# ['4', '7', '9']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-927859d5e7f9> in <module>
#       1 list ='4,7,9'.split(',')
#       2 print(list)
# ----> 3 print(sum(list))
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
list= [4,7,9]
sum(list)
# Out:
# 20

# %%
x= 100
def myfunc():
    x=500
    print(x)
myfunc()
x
# Out:
# 500
# 100

# %%
# 내가 지정한 사용자 정의함수에 의해
# myfunc( 주소값 ) : 결국 def 에 의해서 x=500 이라는 데이터를 불러옴

# %%
x =5
y= 8
x, y= y, x
x, y


#swaping 가능
# Out:
# (8, 5)

# %%
a = [1, 2, 3, ['a', 'b', 'c'], 4, 5]
a[2:5]
# Out:
# [3, ['a', 'b', 'c'], 4]

# %%
a[3]
# Out:
# ['a', 'b', 'c']

# %%
a[3][1] 
# python에서는 첫번째 인덱스 정의는 0 ->자꾸 까먹고 1을 넣게되는 건 습관,
# Out:
# 'b'

# %%
a=[['a',100,200], ['1', 95, 99], ['d', 80, 90]]
a[1][0] #2차원 리스트, 2차원 <- list 안에 list
# Out:
# '1'

# %%
a= [10, 20, 30, 40, 50]
a.append(60)
a
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
a.pop() #누를때 마다 가장 마지막 인덱스 제거함, 4번 눌렀더니 30 out 나온수까지 삭제됨
# Out:
# 30

# %%
a
# Out:
# [10, 20]

# %%
a.append([30, 40, 50, 60]) # append 로 넣으면 list 안에 list 로 들어감
a
# Out:
# [10, 20, [30, 40, 50, 60], [30, 40, 50, 60]]

# %%
a.append(30, 40, 50, 60)
a
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-91-68bbbda1cabc> in <module>
# ----> 1 a.append(30, 40, 50, 60)
#       2 a
#
# TypeError: append() takes exactly one argument (4 given)

# %%
b=(30, 40, 50, 60)
a.append(b) # append 로 list 안에 () :tuple 로 들어감
a
# Out:
# [10, 20, (30, 40, 50, 60), (30, 40, 50, 60), (30, 40, 50, 60)]

# %%
a= [10, 20, 30, 40, 50] 
a.append(60)
a
# Out:
# [10, 20, 30, 40, 50, 60]

# %%
a.pop()
# Out:
# 30

# %%
a.extend([30,40,50,60]) # list 안에 list 가 아닌 수로 넣고 싶을때
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5ca786c725cf> in <module>
# ----> 1 a.extend([30,40,50,60]) # list 안에 list 가 아닌 수로 넣고 싶을때
#       2 a
#
# NameError: name 'a' is not defined
