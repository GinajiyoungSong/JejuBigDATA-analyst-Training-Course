# %%
# pip install customized_konlpy

# %%
def cleanText(readData):
    # 텍스트에 포함되어 있는 특수 문자 제거
    text = re.sub('[-=+,#/\?:^$.@*\"※~&%ㆍ!』\\‘|\(\)\[\]\<\>`\'…》\n_·李永钦타임라인레]', '', readData)
    return text

# %%
import numpy as np

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
from tqdm import tqdm
import pandas as pd
import re



result = []


def scroll(q):
    body = driver.find_element_by_css_selector('body')
    for i in range(q):
        body.send_keys(Keys.PAGE_DOWN)
        time.sleep(1)

def croll():
    for ttt in tqdm(text2):
        result.append(ttt.text)
        
# 코로나 바이러스
keyword = "신천지"

# 웹접속 - 네이버 이미지 접속
# 79.0.3945.36 / chrome version
print("접속중")
driver = webdriver.Chrome(executable_path="./chromedriver.exe")
driver.implicitly_wait(30)

url = 'https://twitter.com/search?q={}&src=typed_query'.format(keyword)
driver.get(url)
time.sleep(3)
text2 = driver.find_elements_by_css_selector('#react-root > div > div > div > main > div > div > div > div > div > div:nth-child(2) > div')


for i in range(30):
    scroll(3)
    croll()
    time.sleep(1)

driver.close()



#     aa = []
#     for q,i in enumerate(result2):
#         aa.append(int(cleanText(i)))
#     result2 = aa



# print('수집완료')


# text2 = driver.find_elements_by_css_selector('span.css-901oao.css-16my406.r-1qd0xha.r-ad9z0x.r-bcqeeo.r-qvutc0')
# text2 = driver.find_elements_by_css_selector('div.css-1dbjc4n')
# Out:
# 접속중
# 100%|██████████| 2/2 [00:01<00:00,  1.09it/s]
# 100%|██████████| 2/2 [00:01<00:00,  1.16it/s]
# 100%|██████████| 2/2 [00:01<00:00,  1.28it/s]
# 100%|██████████| 2/2 [00:01<00:00,  1.22it/s]
# 100%|██████████| 2/2 [00:01<00:00,  1.28it/s]
# 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# 100%|██████████| 2/2 [00:01<00:00,  1.02it/s]
# 100%|██████████| 2/2 [00:01<00:00,  1.03it/s]
# 100%|██████████| 2/2 [00:01<00:00,  1.25it/s]
# 100%|██████████| 2/2 [00:01<00:00,  1.29it/s]
# 100%|██████████| 2/2 [00:01<00:00,  1.12it/s]
# 100%|██████████| 2/2 [00:02<00:00,  1.39s/it]
# 100%|██████████| 2/2 [00:01<00:00,  1.08it/s]
# 100%|██████████| 2/2 [00:01<00:00,  1.35it/s]
# 100%|██████████| 2/2 [00:02<00:00,  1.09s/it]
# 100%|██████████| 2/2 [00:01<00:00,  1.27it/s]
# 100%|██████████| 2/2 [00:02<00:00,  1.26s/it]
# 100%|██████████| 2/2 [00:01<00:00,  1.47it/s]
# 100%|██████████| 2/2 [00:01<00:00,  1.73it/s]
# 100%|██████████| 2/2 [00:01<00:00,  1.47it/s]
# 100%|██████████| 2/2 [00:01<00:00,  1.41it/s]
# 100%|██████████| 2/2 [00:01<00:00,  1.31it/s]
# 100%|██████████| 2/2 [00:01<00:00,  1.92it/s]
# 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# 100%|██████████| 2/2 [00:01<00:00,  1.30it/s]
# 100%|██████████| 2/2 [00:01<00:00,  1.23it/s]
# 100%|██████████| 2/2 [00:01<00:00,  1.17it/s]
# 100%|██████████| 2/2 [00:01<00:00,  1.29it/s]
# 100%|██████████| 2/2 [00:02<00:00,  1.36s/it]
# 100%|██████████| 2/2 [00:01<00:00,  1.26it/s]

# %%
len(result)

# %%
result2 = []
for i in range(len(result)):
    if i % 2 == 0:
        result2.append(result[i])
print(len(result2))
# Out:
# 30

# %%
result3 = []
for i in range(len(result2)):
    result3.append(cleanText(result2[i]))

# %%
import ckonlpy
from ckonlpy.tag import Twitter
ckonlpy.__version__
# Out:
# '0.0.64'

# %%
from ckonlpy.tag import Twitter
t = Twitter()
t.add_dictionary(['트와이스', 'kf94','KF94','Kf94','kF94','타임라인','확진자','예방수칙','코로나19','corona19','Corona19',
                 '개소리','판매','제품','쿠팡','kf94마스크','KF94마스크','Kf94마스크','kF94마스크',
                 '우한폐렴','신종코로나','신종코로나바이러스','coronavirus','Coronavirus','사재기',
                 '복지부장관', '바이러스', '피해복구', '이만희', '문재인', '이재갑','한림대',
                 '감염내과', '교수님', '정치인'], 'Noun')
# Out:
# C:\Users\82105\Anaconda3\envs\Testing\lib\site-packages\konlpy\tag\_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %%
result3[1]
# Out:
# ' 검색따람따람myungjung09055시간신천지가 대한민국 말아먹네 이상황에서도 미통당애들은 신천지에 대한 말한마디 못하고 검찰은 꼼작도 안한다 왜일까044조회수 26천회14246137사랑은빠바박loveispbb3시간단독신천지 새하늘 새땅 으로 법 등록 확돼httpsnocutnewscokrnews5298006이러면 법적 제제가 가능한거 아니냐단독신천지 새하늘 새땅 으로 법 등록 확돼이단 신천지가 의단체로 알려진 것과 달리 사단법 설립 허가를 받은 것으로 확됐다 이단 전문가들은 물론 정부 관계자들마저 신천지가 법이 아니고 이해하고 있는 상황에서 파장이 예상된다 CBS 취재 결nocutnewscokr71660JTBC 뉴스JTBCnews1시간신천지 전수조사 들어갔더니확진 505명 늘어 총 1766명신천지 전수조사 들어갔더니확진 505명 늘어 총 1766명코로나19 환자가 오늘27일만 500명 넘게 늘었습니다 어제 천 명을 넘어선 데 이어 이제 1700명이 넘습니다 신천지 교회 신도들newsjtbcjoinscom319324대구광역시colorfuldg12분사실은 이렇습니다각 가정에 마스크를 나누어 드리는 분은 신천지가 아닌 이통장 공무원 입니다 마스크 190만장을 2월 26일수 각 구군에 배포하였습니다 구군은 이통장 공무원을 통해 마스크를 배부 중예정입니다 우리에게 필요한 것은 따뜻한 말 한마디입니다11696JTBC 뉴스JTBCnews30분예비 신천지 6만5천명 추가정부 31만명 명단 확보예비 신천지 6만5천명 추가정부 31만명 명단 확보신천지가 정부에 낸 신도 명단을 과연 믿을 수 있는지 논란이 돼 왔습니다 신천지는 정부의 요청에 따 6만 5천명의 예비 신도 명newsjtbcjoinscom221036시니오ㄷㅡ6EniJikimi43분신천지 비밀 모 폐쇄명령 하나마나159조회수 309회3113연관 검색대구 코로나청도대구 확진자코로나 증상코로나 대구소비동결히야jiheeeeeeeee41분동대문시장 나갔던 직원이 어떤 원단집 사장님이 쓰러져서 방역복입으신 분들이 데리고 갔다는 소문과 사진을 전해줌 코로나지는 모르겠지만시장 거래처에 전화해서 물어보니 열성 신천지신도고 한다;; 당분간 디자이너들 시장 내보내지말고도 함6513앵그리꾸닥구gooutofmywayfor2시간남편이 폭력 휘둘러서 결국 밖으로 몸을 내던진 것 같은데자살살확실X그걸 남편탓 힘든사람을 꼬셔서 사이비에 입단시킨 신천지탓을 안하고 신천지욕한 국민탓을 한다 이 슬픈 사건을 이용해서 물기시전을 하는 신천지 놈들이 싸이코패스가아니면 뭐란말단독 코로나 사태 이단 프’ 결국 국민을 죽였다 울산 신천지 여신도 추락사  천지일보  새 시대 희망언론코로나 사태 이후 신천지에 대한 비난여론이 커지면서 가정폭력에 시달리던 신천지 여신도가 사망하는 사건이 발생했다27일 울산에 사는 60대 신천지 여신도 A씨가 빌에서 추락해 사망해 경찰이 정확한 사망 newscjcom554585이 스드 보기김홍삼drawingii1시간신천지가 마스크 나눠주는척 한다고 하네요313338이 스드 보기12이홉192Hope47분대한민국 3대 마요신천지 믿지마요신천지 가지마요신천지 오지마요31017無窮花im06424시간신천지에게 묻습니다이 시국에 이게 사실지요22418158스즈무SUZUMURA6시간신천지 교주 얼굴 보다보니까 누구랑 닮았는데 어디서 많이 봤는데 싶었는데 범준씨랑 닮았음215062'

# %%
import nltk
from konlpy.tag import Twitter
import numpy as np
tokens_ko = []

for i in range(len(result3)):
    tokens_ko.append(t.nouns(result3[i]))

# %%
final = []
for _,q in enumerate(tokens_ko):
    for i in range(len(q)):
        final.insert(-1,q[i])

# %%
ko = nltk.Text(final, name="첫번째")
data = ko.vocab().most_common(1000)

# %%
data
# Out:
# [('코로나19', 471),
#  ('시간', 391),
#  ('코로나', 334),
#  ('신천지', 181),
#  ('기부', 145),
#  ('대구', 124),
#  ('명', 104),
#  ('수', 100),
#  ('위해', 100),
#  ('확진자', 96),
#  ('검사', 95),
#  ('이', 88),
#  ('질문', 70),
#  ('확산', 66),
#  ('사태', 64),
#  ('보기', 59),
#  ('중', 59),
#  ('코로나바이러스', 58),
#  ('스드', 56),
#  ('구호', 54),
#  ('뉴스', 53),
#  ('협회', 52),
#  ('사망', 50),
#  ('정부', 49),
#  ('감염', 49),
#  ('등', 49),
#  ('대응', 48),
#  ('감염증', 47),
#  ('슈가', 47),
#  ('내', 46),
#  ('것', 45),
#  ('교회', 45),
#  ('신종', 44),
#  ('재해', 44),
#  ('국민', 44),
#  ('시', 44),
#  ('만원', 43),
#  ('희망', 43),
#  ('울산', 43),
#  ('치료', 43),
#  ('이름', 42),
#  ('조사', 42),
#  ('전국', 41),
#  ('조금', 41),
#  ('발생', 41),
#  ('마스크', 41),
#  ('한국', 40),
#  ('익명', 40),
#  ('방역', 38),
#  ('적', 38),
#  ('단독', 37),
#  ('조심', 37),
#  ('우리', 36),
#  ('바이러스', 36),
#  ('예방', 36),
#  ('모두', 36),
#  ('결과', 36),
#  ('지원', 35),
#  ('성금', 34),
#  ('공무원', 34),
#  ('방탄소년단', 33),
#  ('새', 33),
#  ('고향', 32),
#  ('총', 32),
#  ('대통령', 32),
#  ('검색', 32),
#  ('신도', 32),
#  ('재', 31),
#  ('환자', 30),
#  ('극복', 30),
#  ('여신', 29),
#  ('제', 29),
#  ('대한', 28),
#  ('전', 28),
#  ('병원', 28),
#  ('자', 28),
#  ('힘', 28),
#  ('가운데', 28),
#  ('그', 28),
#  ('동선', 28),
#  ('기금', 27),
#  ('아이유', 27),
#  ('본부', 26),
#  ('고자', 26),
#  ('피해', 26),
#  ('사용', 26),
#  ('확진', 26),
#  ('상자', 26),
#  ('확', 25),
#  ('까지', 25),
#  ('프', 25),
#  ('관련', 25),
#  ('차', 25),
#  ('역학', 25),
#  ('및', 24),
#  ('모든', 24),
#  ('오늘', 24),
#  ('판정', 24),
#  ('추가', 24),
#  ('김요', 24),
#  ('관리', 23),
#  ('씨', 23),
#  ('방지', 23),
#  ('위', 23),
#  ('보', 23),
#  ('안', 23),
#  ('브리지', 23),
#  ('응원', 23),
#  ('사람', 23),
#  ('모', 23),
#  ('재난', 23),
#  ('때문', 22),
#  ('더', 22),
#  ('국내', 22),
#  ('착용', 22),
#  ('공식', 22),
#  ('이유', 22),
#  ('지역', 22),
#  ('엑스', 21),
#  ('중단', 21),
#  ('드립', 21),
#  ('사', 21),
#  ('청원', 21),
#  ('의', 21),
#  ('팬', 21),
#  ('천', 21),
#  ('사진', 21),
#  ('예정', 21),
#  ('배우', 20),
#  ('기준', 20),
#  ('나', 20),
#  ('중앙', 20),
#  ('대책', 20),
#  ('의료', 20),
#  ('연합뉴스', 20),
#  ('안해', 20),
#  ('대전', 20),
#  ('기사', 20),
#  ('동참', 20),
#  ('나눔', 19),
#  ('분', 19),
#  ('생각', 19),
#  ('조회', 19),
#  ('관', 19),
#  ('진행', 19),
#  ('님', 19),
#  ('추락', 19),
#  ('트', 19),
#  ('해주', 19),
#  ('심각', 19),
#  ('현황', 19),
#  ('포함', 18),
#  ('어려움', 18),
#  ('비', 18),
#  ('면서', 18),
#  ('이용', 18),
#  ('대구시', 18),
#  ('예배', 18),
#  ('최근', 18),
#  ('지자체', 18),
#  ('극장', 18),
#  ('피로', 18),
#  ('전주시', 18),
#  ('김연아', 18),
#  ('변', 17),
#  ('업무', 17),
#  ('시장', 17),
#  ('서울', 17),
#  ('리아', 17),
#  ('자비', 17),
#  ('린', 17),
#  ('양성', 17),
#  ('통해', 16),
#  ('보탬', 16),
#  ('소속사', 16),
#  ('기', 16),
#  ('잠정', 16),
#  ('상향', 16),
#  ('구', 16),
#  ('대처', 16),
#  ('무관', 16),
#  ('생', 16),
#  ('공개', 16),
#  ('속', 16),
#  ('이만희', 16),
#  ('지금', 15),
#  ('안내', 15),
#  ('안전', 15),
#  ('세한', 15),
#  ('도움', 15),
#  ('바', 15),
#  ('보고', 15),
#  ('선', 15),
#  ('출처', 15),
#  ('네이버', 15),
#  ('출신', 15),
#  ('도록', 15),
#  ('이단', 15),
#  ('천지일보', 15),
#  ('시대', 15),
#  ('언론', 15),
#  ('요', 15),
#  ('답변', 15),
#  ('사회', 15),
#  ('캐시', 15),
#  ('아이디어', 15),
#  ('건강', 15),
#  ('명단', 15),
#  ('날', 15),
#  ('적극', 15),
#  ('활용', 15),
#  ('입장', 15),
#  ('격리', 15),
#  ('기자', 15),
#  ('기억', 15),
#  ('주조', 15),
#  ('의사', 15),
#  ('소식', 15),
#  ('뮤지컬', 14),
#  ('여러분', 14),
#  ('민', 14),
#  ('사망자', 14),
#  ('조치', 14),
#  ('상황', 14),
#  ('권영진', 14),
#  ('왜', 14),
#  ('집중', 14),
#  ('후', 14),
#  ('모집', 14),
#  ('살', 14),
#  ('금액', 14),
#  ('사실', 14),
#  ('어요', 14),
#  ('법', 14),
#  ('신뢰', 14),
#  ('증상', 14),
#  ('신속', 13),
#  ('음', 13),
#  ('대한민국', 13),
#  ('장', 13),
#  ('지면', 13),
#  ('가정', 13),
#  ('접촉', 13),
#  ('어보', 13),
#  ('수가', 13),
#  ('보건소', 13),
#  ('다음', 13),
#  ('또한', 13),
#  ('대전광역시', 13),
#  ('민주당', 13),
#  ('간', 13),
#  ('구속', 13),
#  ('전해', 12),
#  ('저', 12),
#  ('경북', 12),
#  ('참여', 12),
#  ('합', 12),
#  ('거', 12),
#  ('번', 12),
#  ('속보', 12),
#  ('후원', 12),
#  ('주시', 12),
#  ('탄핵', 12),
#  ('돕기', 12),
#  ('원', 12),
#  ('김', 12),
#  ('천시', 12),
#  ('백', 12),
#  ('처', 12),
#  ('리', 12),
#  ('하루', 12),
#  ('목', 12),
#  ('고', 12),
#  ('송', 12),
#  ('개', 12),
#  ('의심', 12),
#  ('벌교', 12),
#  ('강찬', 12),
#  ('이시언', 12),
#  ('용', 12),
#  ('브리핑', 12),
#  ('부산', 12),
#  ('대선', 12),
#  ('방호복', 12),
#  ('교주', 12),
#  ('검찰', 12),
#  ('고발', 12),
#  ('제출', 12),
#  ('누적', 12),
#  ('까운', 12),
#  ('김소현', 12),
#  ('습', 11),
#  ('내용', 11),
#  ('달', 11),
#  ('청와대', 11),
#  ('의미', 11),
#  ('취소', 11),
#  ('네', 11),
#  ('상', 11),
#  ('몸', 11),
#  ('독', 11),
#  ('경찰', 11),
#  ('이벤트', 11),
#  ('활동', 11),
#  ('자체', 11),
#  ('스', 11),
#  ('시민', 11),
#  ('이도', 11),
#  ('교', 11),
#  ('쾌척', 11),
#  ('이동', 11),
#  ('발열', 11),
#  ('청', 11),
#  ('진', 11),
#  ('때', 11),
#  ('검진', 11),
#  ('진정', 10),
#  ('이상', 10),
#  ('위원회', 10),
#  ('달리', 10),
#  ('감사', 10),
#  ('거나', 10),
#  ('가수', 10),
#  ('가장', 10),
#  ('주일', 10),
#  ('그대로', 10),
#  ('마음', 10),
#  ('곳', 10),
#  ('급증', 10),
#  ('트윗', 10),
#  ('못', 10),
#  ('윤기', 10),
#  ('새벽', 10),
#  ('금일', 10),
#  ('자기', 10),
#  ('전달', 10),
#  ('전쟁', 10),
#  ('지휘', 10),
#  ('행사', 10),
#  ('자가', 10),
#  ('해주시', 10),
#  ('정확', 9),
#  ('미디어', 9),
#  ('민감', 9),
#  ('콘텐츠', 9),
#  ('설정', 9),
#  ('경보기', 9),
#  ('관계자', 9),
#  ('피해복구', 9),
#  ('관객', 9),
#  ('부탁', 9),
#  ('책', 9),
#  ('캠페', 9),
#  ('건', 9),
#  ('내세', 9),
#  ('사건', 9),
#  ('말', 9),
#  ('트친', 9),
#  ('불안', 9),
#  ('자신', 9),
#  ('화제', 9),
#  ('외신', 9),
#  ('로', 9),
#  ('집회', 9),
#  ('문프', 9),
#  ('팀', 9),
#  ('마', 9),
#  ('녀', 9),
#  ('도', 9),
#  ('종식', 9),
#  ('행정안전부', 9),
#  ('독려', 9),
#  ('증', 9),
#  ('회', 9),
#  ('마포구', 9),
#  ('콘서트', 9),
#  ('공지', 9),
#  ('무', 9),
#  ('신협', 9),
#  ('음성', 9),
#  ('배달', 9),
#  ('소독제', 9),
#  ('산림', 9),
#  ('알코올', 9),
#  ('원료', 9),
#  ('장난', 9),
#  ('혐의', 9),
#  ('철저', 9),
#  ('위자료', 9),
#  ('전광훈', 9),
#  ('무덤', 9),
#  ('투석', 9),
#  ('사탕', 8),
#  ('다자', 8),
#  ('이나', 8),
#  ('과', 8),
#  ('제이지', 8),
#  ('역할', 8),
#  ('앨범', 8),
#  ('이면', 8),
#  ('오후', 8),
#  ('국내외', 8),
#  ('비난', 8),
#  ('중국', 8),
#  ('물', 8),
#  ('팬카페', 8),
#  ('안철수', 8),
#  ('여파', 8),
#  ('가세', 8),
#  ('방법', 8),
#  ('총력전', 8),
#  ('종지부', 8),
#  ('소독', 8),
#  ('로맨스', 8),
#  ('대상', 8),
#  ('초점', 8),
#  ('소속', 8),
#  ('알티', 8),
#  ('시간대', 8),
#  ('파악', 8),
#  ('이번', 8),
#  ('각하', 8),
#  ('경우', 8),
#  ('신', 8),
#  ('최고', 8),
#  ('예비', 8),
#  ('후보', 8),
#  ('낼', 8),
#  ('개봉', 8),
#  ('통과', 8),
#  ('유지', 8),
#  ('극적', 8),
#  ('감염병', 8),
#  ('신천지예수교', 8),
#  ('주말', 8),
#  ('부시장', 8),
#  ('유전자', 8),
#  ('의식주', 8),
#  ('퇴근길', 8),
#  ('폐렴', 8),
#  ('일', 8),
#  ('열심', 8),
#  ('부천시', 8),
#  ('미국', 8),
#  ('대화', 8),
#  ('의전', 8),
#  ('쟁', 8),
#  ('대해', 7),
#  ('질병', 7),
#  ('콜센터', 7),
#  ('중증', 7),
#  ('김태형', 7),
#  ('증가', 7),
#  ('신규', 7),
#  ('최우', 7),
#  ('경제', 7),
#  ('역시', 7),
#  ('매일신문', 7),
#  ('사이비', 7),
#  ('욕', 7),
#  ('이후', 7),
#  ('여론', 7),
#  ('가정폭력', 7),
#  ('던', 7),
#  ('소', 7),
#  ('정', 7),
#  ('생일', 7),
#  ('곧', 7),
#  ('술', 7),
#  ('지고', 7),
#  ('강력', 7),
#  ('국가', 7),
#  ('점', 7),
#  ('모금', 7),
#  ('당분간', 7),
#  ('함', 7),
#  ('영국', 7),
#  ('공', 7),
#  ('제파', 7),
#  ('아미', 7),
#  ('건가', 7),
#  ('일일', 7),
#  ('알림', 7),
#  ('명자', 7),
#  ('추후', 7),
#  ('언니', 7),
#  ('로부터', 7),
#  ('어진', 7),
#  ('음으로', 7),
#  ('아래', 7),
#  ('영화', 7),
#  ('경로', 7),
#  ('채', 7),
#  ('거짓말', 7),
#  ('안녕', 7),
#  ('연기', 7),
#  ('행', 7),
#  ('기침', 7),
#  ('양해', 7),
#  ('조만간', 7),
#  ('요한', 7),
#  ('트럼프', 7),
#  ('누가', 6),
#  ('공연', 6),
#  ('설명', 6),
#  ('망', 6),
#  ('당일', 6),
#  ('개최', 6),
#  ('물어', 6),
#  ('질', 6),
#  ('대결', 6),
#  ('파이낸셜뉴스', 6),
#  ('예', 6),
#  ('제목', 6),
#  ('탓', 6),
#  ('소액', 6),
#  ('아트', 6),
#  ('둘', 6),
#  ('너', 6),
#  ('언제', 6),
#  ('주', 6),
#  ('천경', 6),
#  ('리기', 6),
#  ('최대', 6),
#  ('비율', 6),
#  ('혜택', 6),
#  ('맹점', 6),
#  ('요소', 6),
#  ('상공', 6),
#  ('미추홀', 6),
#  ('사항', 6),
#  ('집', 6),
#  ('특파원', 6),
#  ('다시', 6),
#  ('한번', 6),
#  ('기발', 6),
#  ('적용', 6),
#  ('마련', 6),
#  ('이브', 6),
#  ('닉', 6),
#  ('이프', 6),
#  ('신문', 6),
#  ('아주', 6),
#  ('여의도순복음교회', 6),
#  ('달빛', 6),
#  ('이제', 6),
#  ('토왜', 6),
#  ('운동', 6),
#  ('유닛', 6),
#  ('시구', 6),
#  ('무죄', 6),
#  ('죄녀', 6),
#  ('다그', 6),
#  ('오프', 6),
#  ('정책', 6),
#  ('교육', 6),
#  ('명의', 6),
#  ('입수', 6),
#  ('제외', 6),
#  ('율', 6),
#  ('낮', 6),
#  ('발', 6),
#  ('힐링', 6),
#  ('맵솔콘', 6),
#  ('통보', 6),
#  ('조기', 6),
#  ('아이', 6),
#  ('제한', 6),
#  ('원유', 6),
#  ('닛', 6),
#  ('손', 6),
#  ('증명사진', 6),
#  ('소담', 6),
#  ('지기', 6),
#  ('거창', 6),
#  ('불어', 6),
#  ('구미', 6),
#  ('갑', 6),
#  ('출장', 6),
#  ('정치', 6),
#  ('숙자', 6),
#  ('현재', 6),
#  ('승객', 6),
#  ('위기', 6),
#  ('배려', 6),
#  ('생활', 6),
#  ('민경', 6),
#  ('김화', 6),
#  ('일정', 6),
#  ('수행', 6),
#  ('결제', 6),
#  ('어도', 6),
#  ('현', 6),
#  ('락스', 6),
#  ('석', 6),
#  ('증세', 6),
#  ('국립', 6),
#  ('학원', 6),
#  ('홍릉', 6),
#  ('시험', 6),
#  ('림', 6),
#  ('숲', 6),
#  ('해설', 6),
#  ('방송', 6),
#  ('정례', 6),
#  ('coronavirus', 6),
#  ('주류', 6),
#  ('주정', 6),
#  ('소주', 6),
#  ('점령', 6),
#  ('앞', 6),
#  ('유급', 6),
#  ('휴가', 6),
#  ('신청', 6),
#  ('사용자', 6),
#  ('매일', 6),
#  ('모나', 6),
#  ('방문', 6),
#  ('허위', 6),
#  ('진술', 6),
#  ('첫', 6),
#  ('증거', 6),
#  ('남성', 6),
#  ('중이', 6),
#  ('세상', 6),
#  ('길', 6),
#  ('포트', 6),
#  ('스포', 6),
#  ('티비', 6),
#  ('일혈', 6),
#  ('맹', 6),
#  ('뿐', 6),
#  ('회장', 6),
#  ('고시', 6),
#  ('전수', 6),
#  ('야근', 6),
#  ('비상근', 6),
#  ('피겨', 6),
#  ('자랑', 6),
#  ('유니세프', 6),
#  ('금은', 6),
#  ('자마자', 6),
#  ('천만원', 6),
#  ('뭐', 6),
#  ('입국', 6),
#  ('천사', 6),
#  ('글', 6),
#  ('이미지', 5),
#  ('주기', 5),
#  ('계속', 5),
#  ('조속', 5),
#  ('직면', 5),
#  ('민생', 5),
#  ('고삐', 5),
#  ('한순간', 5),
#  ('해당', 5),
#  ('문의', 5),
#  ('즉각', 5),
#  ('돈', 5),
#  ('이틀', 5),
#  ('해결', 5),
#  ('해지', 5),
#  ('문', 5),
#  ('고통', 5),
#  ('대우', 5),
#  ('놈', 5),
#  ('면', 5),
#  ('진짜', 5),
#  ('병', 5),
#  ('하나', 5),
#  ('방', 5),
#  ('대표', 5),
#  ('봇', 5),
#  ('메시지', 5),
#  ('아리', 5),
#  ('김재규', 5),
#  ('영웅', 5),
#  ('서초동', 5),
#  ('파', 5),
#  ('국', 5),
#  ('기기', 5),
#  ('아무', 5),
#  ('공간', 5),
#  ('숨', 5),
#  ('민윤기', 5),
#  ('이슈', 5),
#  ('차이', 5),
#  ('초콜릿', 5),
#  ('남', 5),
#  ('수도', 5),
#  ('연예', 5),
#  ('오전', 5),
#  ('착', 5),
#  ('누구', 5),
#  ('법률', 5),
#  ('사랑', 5),
#  ('폐쇄', 5),
#  ('성도', 5),
#  ('주민', 5),
#  ('수고', 5),
#  ('신종코로나', 5),
#  ('국회의원', 5),
#  ('봉사', 5),
#  ('부분', 5),
#  ('박스', 5),
#  ('충북', 5),
#  ('위생', 5),
#  ('준수', 5),
#  ('상담', 5),
#  ('이웃', 5),
#  ('대가', 5),
#  ('전체', 5),
#  ('다대', 5),
#  ('기독교', 5),
#  ('협조', 5),
#  ('온', 5),
#  ('이외', 5),
#  ('반드시', 5),
#  ('나비', 5),
#  ('전하', 5),
#  ('바탕', 5),
#  ('감', 5),
#  ('변화', 5),
#  ('분석', 5),
#  ('참고', 5),
#  ('며', 5),
#  ('다른', 5),
#  ('혼자', 5),
#  ('금지', 5),
#  ('정보', 4),
#  ('보건복지부', 4),
#  ('제공', 4),
#  ('를', 4),
#  ('지민', 4),
#  ('가오', 4),
#  ('관람', 4),
#  ('객', 4),
#  ('뷔', 4),
#  ('애', 4),
#  ('회사', 4),
#  ('저번', 4),
#  ('얼른', 4),
#  ('전파', 4),
#  ('움직', 4),
#  ('남편', 4),
#  ('재민', 4),
#  ('엽니', 4),
#  ('데이', 4),
#  ('고민', 4),
#  ('나이', 4),
#  ('어서', 4),
#  ('박예림', 4),
#  ('긴급', 4),
#  ('제언', 4),
#  ('계엄령', 4),
#  ('수준', 4),
#  ('필', 4),
#  ('대국민', 4),
#  ('전담', 4),
#  ('기관', 4),
#  ('마네키네코', 4),
#  ('노래', 4),
#  ('연습장', 4),
#  ('전지', 4),
#  ('작업', 4),
#  ('실시', 4),
#  ('남궁민', 4),
#  ('송가', 4),
#  ('어', 4),
#  ('좀', 4),
#  ('오', 4),
#  ('행복', 4),
#  ('세계', 4),
#  ('부담', 4),
#  ('건물', 4),
#  ('대료', 4),
#  ('주가', 4),
#  ('금', 4),
#  ('김종현', 4),
#  ('분속', 4),
#  ('외출', 4),
#  ('팔로우', 4),
#  ('화명동', 4),
#  ('다지', 4),
#  ('반', 4),
#  ('느낌', 4),
#  ('이예', 4),
#  ('사지', 4),
#  ('기만', 4),
#  ('하루하루', 4),
#  ('요시', 4),
#  ('연', 4),
#  ('햇살', 4),
#  ('미소', 4),
#  ('그날', 4),
#  ('렛또', 4),
#  ('이승기', 4),
#  ('보호', 4),
#  ('무대', 4),
#  ('소나기', 4),
#  ('쟈키', 4),
#  ('홍마눈', 4),
#  ('이상은', 4),
#  ('땡', 4),
#  ('얼', 4),
#  ('칭찬', 4),
#  ('멋', 4),
#  ('챠', 4),
#  ('넌', 4),
#  ('야기', 4),
#  ('하단', 4),
#  ('추천', 4),
#  ('주심', 4),
#  ('고마', 4),
#  ('구니', 4),
#  ('무하', 4),
#  ('김철호', 4),
#  ('자제', 4),
#  ('코랄', 4),
#  ('법사', 4),
#  ('총리', 4),
#  ('본부장', 4),
#  ('손상', 4),
#  ('과장', 4),
#  ('왜곡', 4),
#  ('공세', 4),
#  ('방어', 4),
#  ('취켓팅', 4),
#  ('집단', 4),
#  ('쟈니', 4),
#  ('대거', 4),
#  ('요청', 4),
#  ('개신교', 4),
#  ('천주교', 4),
#  ('불교', 4),
#  ('엔젤', 4),
#  ('님들', 4),
#  ('다모', 4),
#  ('열', 4),
#  ('꼭', 4),
#  ('비서', 4),
#  ('비공개', 4),
#  ('최소', 4),
#  ('발견', 4),
#  ('돌변', 4),
#  ('이로', 4),
#  ('갑작', 4),
#  ('독성', 4),
#  ('리나', 4),
#  ('오류', 4),
#  ('가능성', 4),
#  ('거의', 4),
#  ('향후', 4),
#  ('경보', 4),
#  ('단계', 4),
#  ('조정', 4),
#  ('다감', 4),
#  ('찬', 4),
#  ('지오', 4),
#  ('가배', 4),
#  ('가재', 4),
#  ('기하', 4),
#  ('눈', 4),
#  ('민주', 4),
#  ('노총', 4),
#  ('노동자', 4),
#  ('기자회견', 4),
#  ('문제', 4),
#  ('윤슬', 4),
#  ('상아', 4),
#  ('중고', 4),
#  ('짐', 4),
#  ('새끼', 4),
#  ('버그', 4),
#  ('정권', 4),
#  ('나머지', 4),
#  ('다리', 4),
#  ('대기', 4),
#  ('이지', 4),
#  ('여행', 4),
#  ('봉합', 4),
#  ('매우', 4),
#  ('한산', 4),
#  ('상해', 4),
#  ('프로듀서', 4),
#  ('재개', 4),
#  ('개봉관', 4),
#  ('격상', 4),
#  ('추이', 4),
#  ('개봉일', 4),
#  ('확정', 4),
#  ('예방수칙', 4),
#  ('꼭지', 4),
#  ('일개', 4),
#  ('봉', 4),
#  ('방탄', 4),
#  ('그동안', 4),
#  ('리셋', 4),
#  ('대가리', 4),
#  ('뇌', 4),
#  ('다다', 3),
#  ('샤이닝', 3),
#  ('온리전', 3),
#  ('스쿨', 3),
#  ('강하', 3),
#  ('요다음', 3),
#  ('씨발', 3),
#  ('방금', 3),
#  ('걔네', 3),
#  ('엔터테먼트', 3),
#  ('지하', 3),
#  ('당신', 3),
#  ('만큼', 3),
#  ('토착', 3),
#  ('왜구', 3),
#  ('수구', 3),
#  ('꼴통', 3),
#  ('오히려', 3),
#  ('이간', 3),
#  ('가열', 3),
#  ('산세', 3),
#  ('지속', 3),
#  ('구도', 3),
#  ('촉', 3),
#  ('구합', 3),
#  ('동의', 3),
#  ('골든', 3),
#  ('멤버', 3),
#  ('신종코로나바이러스', 3),
#  ('이하', 3),
#  ('진압', 3),
#  ('블락', 3),
#  ('김재범', 3),
#  ('백암', 3),
#  ('홀', 3),
#  ('일자', 3),
#  ('곤란', 3),
#  ('무능', 3),
#  ('지리', 3),
#  ('비판', 3),
#  ('목소리', 3),
#  ('오마이', 3),
#  ('주민등록', 3),
#  ('배우자', 3),
#  ('소재', 3),
#  ('초등학교', 3),
#  ('교사', 3),
#  ('자녀', 3),
#  ('검체', 3),
#  ('소비', 3),
#  ('동결', 3),
#  ('히', 3),
#  ('동대문시장', 3),
#  ('직원', 3),
#  ('원단', 3),
#  ('장님', 3),
#  ('복', 3),
#  ('데리', 3),
#  ('소문', 3),
#  ('줌', 3),
#  ('거래처', 3),
#  ('전화', 3),
#  ('열성', 3),
#  ('신도고', 3),
#  ('디자이너', 3),
#  ('내지', 3),
#  ('혁신', 3),
#  ('입증', 3),
#  ('관심', 3),
#  ('비커', 3),
#  ('영남대', 3),
#  ('드', 3),
#  ('스루', 3),
#  ('박연', 3),
#  ('화기', 3),
#  ('돌파', 3),
#  ('지방자치단체', 3),
#  ('민간', 3),
#  ('리지', 3),
#  ('참신', 3),
#  ('개신교회', 3),
#  ('열기', 3),
#  ('이변', 3),
#  ('연돌', 3),
#  ('공수', 3),
#  ('완성', 3),
#  ('서초', 3),
#  ('최후', 3),
#  ('승리', 3),
#  ('신들', 3),
#  ('극찬', 3),
#  ('현실', 3),
#  ('데노', 3),
#  ('이해', 3),
#  ('죄녀죄녀', 3),
#  ('닌텐도', 3),
#  ('골달', 3),
#  ('페잉', 3),
#  ('가사도', 3),
#  ('잇힛', 3)]

# %%
import requests
from bs4 import BeautifulSoup
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import nltk
from konlpy.tag import Twitter
import numpy as np
from PIL import Image

tmp_data = dict(data)

wordcloud = WordCloud( font_path = '/Library/Fonts/NanumMyeongjo.ttf',
                       background_color='white').generate_from_frequencies(tmp_data)
plt.figure(figsize=(16,8))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
import nltk
from konlpy.tag import Twitter
import numpy as np
re3 = []


t = Twitter()
tokens_ko = t.nouns(result2[0])
tokens_ko2 = t.nouns(result2[1])
# ko = nltk.Text(tokens_ko, name="첫번째")
# ko.vocab().most_common(10)
# data = ko.vocab().most_common(1000)

# %%
for i in range(len(tokens_ko)):
    tokens_ko.insert(-1,tokens_ko2[i])

# %%
ko = nltk.Text(tokens_ko, name="첫번째")
ko.vocab().most_common(10)
data = ko.vocab().most_common(1000)

# %%
data
# Out:
# [('폐렴', 56),
#  ('우한', 52),
#  ('코로나', 26),
#  ('대표', 17),
#  ('확', 17),
#  ('진자', 17),
#  ('황교안', 14),
#  ('미로', 14),
#  ('혈세', 14),
#  ('말', 12),
#  ('대구', 12),
#  ('황', 10),
#  ('뉴스', 9),
#  ('붓기', 9),
#  ('지역', 8),
#  ('중국', 8),
#  ('성동구', 8),
#  ('사회', 7),
#  ('불안', 7),
#  ('고', 7),
#  ('오전', 7),
#  ('대응', 7),
#  ('하루', 7),
#  ('사람', 7),
#  ('발생', 7),
#  ('이', 6),
#  ('확산', 6),
#  ('주장', 6),
#  ('정부', 6),
#  ('비난', 6),
#  ('입국', 6),
#  ('계속', 6),
#  ('세', 6),
#  ('남성', 6),
#  ('감염', 6),
#  ('중국인', 6),
#  ('이데일리', 5),
#  ('장', 5),
#  ('영락', 5),
#  ('기자', 5),
#  ('시민', 5),
#  ('가운데', 5),
#  ('자유', 5),
#  ('한국', 5),
#  ('국회', 5),
#  ('최고', 5),
#  ('위원', 5),
#  ('회의', 5),
#  ('상황', 5),
#  ('어제', 5),
#  ('무려', 5),
#  ('여명', 5),
#  ('폭증', 5),
#  ('며', 5),
#  ('대구시', 5),
#  ('혐오', 5),
#  ('방역', 5),
#  ('금지', 5),
#  ('검색', 4),
#  ('신종', 4),
#  ('가짜', 4),
#  ('나라', 4),
#  ('먼저', 4),
#  ('권영진', 4),
#  ('사망자', 4),
#  ('일', 4),
#  ('책임', 4),
#  ('겨울', 4),
#  ('명', 4),
#  ('문재인', 4),
#  ('문제', 4),
#  ('짜파구리', 4),
#  ('동안', 4),
#  ('속보', 4),
#  ('확진', 4),
#  ('해외', 4),
#  ('여행', 4),
#  ('접촉', 4),
#  ('또', 4),
#  ('망', 4),
#  ('밖', 4),
#  ('재', 4),
#  ('것', 4),
#  ('통해', 3),
#  ('다음', 3),
#  ('메르스', 3),
#  ('사태', 3),
#  ('보기', 3),
#  ('고집', 3),
#  ('이제', 3),
#  ('국가', 3),
#  ('경북', 3),
#  ('대한민국', 3),
#  ('환자', 3),
#  ('피하', 3),
#  ('재앙', 3),
#  ('신천지', 3),
#  ('국민', 3),
#  ('타임', 2),
#  ('라인', 2),
#  ('코로나바이러스', 2),
#  ('감염증', 2),
#  ('정보', 2),
#  ('확인', 2),
#  ('질병', 2),
#  ('관리', 2),
#  ('본부', 2),
#  ('대한', 2),
#  ('커녕', 2),
#  ('처단', 2),
#  ('토착', 2),
#  ('왜구', 2),
#  ('총리', 2),
#  ('바이러스', 2),
#  ('상식', 2),
#  ('통', 2),
#  ('조롱', 2),
#  ('말씀', 2),
#  ('당신', 2),
#  ('좀', 2),
#  ('송영', 2),
#  ('훈', 2),
#  ('일명', 2),
#  ('세번', 2),
#  ('남성은', 2),
#  ('기침약', 2),
#  ('처방', 2),
#  ('가능성', 2),
#  ('일부', 2),
#  ('초기', 2),
#  ('단', 2),
#  ('쉽사리', 2),
#  ('수', 2),
#  ('몫', 2),
#  ('고인', 2),
#  ('명복', 2),
#  ('바다', 2),
#  ('첫', 2),
#  ('날', 2),
#  ('달', 2),
#  ('과도', 2),
#  ('규제', 2),
#  ('완화', 2),
#  ('회식', 2),
#  ('장려', 2),
#  ('이재용', 2),
#  ('국내', 2),
#  ('안정화', 2),
#  ('마음', 2),
#  ('아픔', 2),
#  ('관광객', 2),
#  ('모기', 2),
#  ('타원형', 2),
#  ('고양이', 2),
#  ('영화', 2),
#  ('사모님', 2),
#  ('기택', 2),
#  ('홍수', 2),
#  ('물이', 2),
#  ('가득', 2),
#  ('청와대', 2),
#  ('김정숙', 2),
#  ('인', 2),
#  ('서울', 2),
#  ('해외여행', 2),
#  ('간', 2),
#  ('적', 2),
#  ('정원', 2),
#  ('오', 2),
#  ('동구청', 2),
#  ('자신', 2),
#  ('페이스북', 2),
#  ('조선일보', 2),
#  ('무단', 2),
#  ('및', 2),
#  ('배포', 2),
#  ('연관', 2),
#  ('천지일보', 2),
#  ('응원', 2),
#  ('게', 2),
#  ('온', 2),
#  ('독일', 2),
#  ('프로', 2),
#  ('백수', 2),
#  ('탄핵', 2),
#  ('진원', 2),
#  ('못', 2),
#  ('피해자', 2),
#  ('스레드', 2),
#  ('마스크', 2),
#  ('전파', 2),
#  ('대량', 2),
#  ('신속', 1),
#  ('정확', 1),
#  ('대해', 1),
#  ('보건복지부', 1),
#  ('최신', 1),
#  ('제공', 1),
#  ('홈페이지', 1),
#  ('콜센터', 1),
#  ('를', 1),
#  ('지금', 1),
#  ('키', 1),
#  ('정신', 1),
#  ('표', 1),
#  ('죽창', 1),
#  ('죽', 1),
#  ('소리', 1),
#  ('친일파', 1),
#  ('후손', 1),
#  ('홍만표', 1),
#  ('이인규', 1),
#  ('병', 1),
#  ('처벌', 1),
#  ('장제원', 1),
#  ('조사', 1),
#  ('새끼', 1),
#  ('때', 1),
#  ('추경', 1),
#  ('액', 1),
#  ('메', 1),
#  ('편전', 1),
#  ('자고', 1),
#  ('당인', 1),
#  ('데', 1),
#  ('트윗', 1),
#  ('인용', 1),
#  ('안', 1),
#  ('용어', 1),
#  ('인기', 1),
#  ('조장혁', 1),
#  ('더니', 1),
#  ('줄', 1),
#  ('연예인', 1),
#  ('발언', 1),
#  ('사용자', 1),
#  ('팔로우', 1),
#  ('모두', 1),
#  ('아침', 1),
#  ('기자회견', 1),
#  ('문', 1),
#  ('세상', 1),
#  ('묘', 1),
#  ('생각', 1),
#  ('그', 1),
#  ('소속', 1),
#  ('내내', 1),
#  ('봉쇄', 1),
#  ('해', 1),
#  ('일주일', 1),
#  ('사이', 1),
#  ('형세', 1),
#  ('반성은', 1),
#  ('검', 1),
#  ('푸른새', 1),
#  ('표현', 1),
#  ('명칭', 1),
#  ('에스더', 1),
#  ('국', 1),
#  ('짱개', 1),
#  ('개국', 1),
#  ('아시아', 1),
#  ('페스트', 1),
#  ('창궐', 1),
#  ('독일인', 1),
#  ('피', 1),
#  ('로', 1),
#  ('단정', 1),
#  ('병신', 1),
#  ('육갑', 1),
#  ('당장', 1),
#  ('일본', 1),
#  ('일만', 1),
#  ('쪽바리', 1),
#  ('어쩌', 1),
#  ('오지', 1),
#  ('누가', 1),
#  ('뭐', 1),
#  ('도', 1),
#  ('유입', 1),
#  ('차단', 1),
#  ('멸절', 1),
#  ('네네', 1),
#  ('그냥', 1),
#  ('천지', 1),
#  ('요', 1),
#  ('역시', 1),
#  ('다운', 1),
#  ('미제', 1),
#  ('거리', 1),
#  ('시절', 1),
#  ('메롱', 1),
#  ('꼭', 1),
#  ('김정은', 1),
#  ('시진핑', 1),
#  ('경험', 1),
#  ('소주', 1),
#  ('최저임금', 1),
#  ('탈', 1),
#  ('원전', 1),
#  ('경제', 1),
#  ('거덜', 1),
#  ('소독제', 1),
#  ('간곳', 1),
#  ('마트', 1),
#  ('생필', 1),
#  ('난', 1),
#  ('고통', 1),
#  ('정숙', 1),
#  ('입', 1),
#  ('광일', 1),
#  ('실제', 1),
#  ('슈퍼', 1),
#  ('방치', 1),
#  ('중공', 1),
#  ('피해', 1),
#  ('전적', 1),
#  ('안보', 1),
#  ('전염병', 1),
#  ('각심', 1),
#  ('관광', 1),
#  ('제한', 1),
#  ('집회', 1),
#  ('제등', 1),
#  ('제대로', 1),
#  ('대처', 1),
#  ('곧', 1),
#  ('종식', 1),
#  ('라며', 1),
#  ('정상', 1),
#  ('활동', 1),
#  ('하라', 1)]

# %%
# 페이지 스크롤 다운
# body = driver.find_element_by_css_selector('body')
# for i in range(150):
#     body.send_keys(Keys.PAGE_DOWN)
#     time.sleep(1)

# # 이미지 링크 수집
# imgs = driver.find_elements_by_css_selector('img._img')
# result = []
# for img in tqdm(imgs):
#     if 'http' in img.get_attribute('src'):
#         result.append(img.get_attribute('src'))
# # print(result)
#
# driver.close()
# print('수집완료')
#
# # 파일 저장
# import os
# if not os.path.isdir('./{}'.format(key)):
#     print('폴더생성')
#     os.mkdir('./{}'.format(key))
#
# # 다운로드
# from urllib.request import urlretrieve
#
# print("다운로드중")
# for index, link in tqdm(enumerate(result)):
#     start = link.rfind('.')
#     end = link.rfind('&')
#     # print(link[start:end])
#     filetype = link[start:end]
#     if filetype == '.jpg':  # jpg 만 다운
#         urlretrieve(link, './{}/{}{}{}'.format(key, key, index, filetype))
#         time.sleep(1)
# print("다운로드 완료")
#
# # import zipfile
# # zip_file = zipfile.Zipfile('./{}.zip'.format(keyword),'w')
# # # 이 폴더안에 파일 가져오는거
# # for image in tqdm(os.listdir('./{}'.format(keyword))):
# #     zip_file.write('./{}/{}'.format(keyword,image), compress_type=zip_file.ZIP_DEFLATED)
# # zip_file.close()
# # print("압축완료")
