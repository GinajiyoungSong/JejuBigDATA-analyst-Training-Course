# %% [markdown]
# # Mariadb 설치하기

# %%
Mariadb foundation 사이트에서
Downloads 하기

https://downloads.mariadb.org/
    
10.4.11 stable.Now ! 선택

mariadb-10.4.11-winx64.msi
패키지타임 : MSI Package 로 다운
# Out:
#   File "<ipython-input-1-7373c9fe9922>", line 1
#     Mariadb foundation 사이트에서
#                      ^
# SyntaxError: invalid syntax

# %%
설치 =>

        경로 : C:\Program Files\MariaDB 10.4\ 
        경로 잘 확인할것
        
        Modify password 
        패스워드 넣을때, VtBox 실행할때 만든 비밀번호 동일하게 넣고 넥스트
    
        enable netwalking tcp port 3306 으로 잘 되어있고

        enable 어쩌고 플러그인 피드백 뭐시기는 체크하지 말것!

# %% [markdown]
# # 설치 완료 /  heidiSQL 설치하기

# %%
mariadb 설치후
heidiSQL 설치하기
select Additional tasks 에서
옵션 4개다 체크 놔두고
아래 테마  - dark 로

설치완료


왼쪽하단 
신규 눌러서
설정 => 패스워드 넣고 열기

# %% [markdown]
# # heidiSQL 실행

# %%
unnamed 큰창에서 오른쪽 마우스버튼 새로생성
=> 데이터베이스 : jeju
    
    jeju : 오른쪽 마우스버튼 새로생성
    => 테이블
    
    
    테이블 이름 : authors
        열 추가 = 이름 바꿔주고 데이터타입 INT => VARCHAR 로 바꿔줌 (길이:50)
