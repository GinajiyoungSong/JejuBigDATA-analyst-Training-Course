# %%
# 2축 그래프 그리기, 한개의 그래프에 2개의 좌우, y축 그리기

https://m.blog.naver.com/PostView.nhn?blogId=onlyjeje&logNo=221168953266&proxyReferer=https%3A%2F%2Fwww.google.com%2F

# %%
import numpy as np
import matplotlib.pyplot as plt

fig, ax1 = plt.subplot()
ax2 = ax1.twinx()

# 데이터 불러오기
# plot with properties
line1 = ax1.plot(x1, y1, color='b', linestyle='--', marker='o', # 동그란점
                label=title[1]) # 그래프 형태 스타일로 나누기
line2 = ax1.plot(x2, y2, color='g', linestyle='--', marker='^',
                label=title[2])
line3 = ax1.plot(x3, y3, clolor='r', linestyle='--', marker='s',
                label=title[3])

# y축 범위 지정
ax1.set_ylim(0,1600)
ax2.set_ylim(2.0,6.0)

# plot legend for all y axis
lines = line1 + line2 + line3
labels=[l.get_label() for l in lines]
plt.legend(lines,labels, loc=2) #??? 이렇게 해서 legend 가 다 그려지나?
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-caa7f5dec44e> in <module>
#       2 import matplotlib.pyplot as plt
#       3
# ----> 4 fig, ax1 = plt.subplot()
#       5 ax2 = ax1.twinx()
#       6
#
# TypeError: cannot unpack non-iterable AxesSubplot object

# %%
# 어노테이션

그래프에 화살표를 그린후, 그 화살표에 문자열을 출력하는 기능
예를들어 “이값이 최소값" 이런식으로 화살표를 그려서 표현할때 사용하는데
plt.annotate 함수를 사용하면 된다.

plt.annotate(‘문자열',xy, xytext, arrowprops) 식으로 사용한다.

문자열은 어노테이션에서 나타낼 문자열이고,
xy는 화살표가 가르키는 점의 위치, xytext는 문자열이 출력될 위치, 
arrowprops는 화살표의 속성으로 칼라등을 정의한다.



출처: https://bcho.tistory.com/1201 [조대협의 블로그]

# %%
from matplotlib import pyplot as plt
import numpy as np

x = np.arange(1,10)
y = x*5

plt.plot(x,y)
plt.annotate('annotate',xy=(2,10),xytext=(5,20),arrowprops={'color':'green'})
plt.show()
